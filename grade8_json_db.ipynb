# %% [markdown]
# <a href="https://colab.research.google.com/github/yeshamcelzo/firebase-upload/blob/main/grade8_json_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = "https://raw.githubusercontent.com/yeshamcelzo/firebase-upload/refs/heads/main/students.JSON"
response = requests.get(url)
students = response.json()
print(students)
#make sure the url is the raw file from the github
# Out:
# {'students': [{'id': 1001, 'name': 'Czarina', 'grades': {'Math': 92, 'CS': 88}}, {'id': 1002, 'name': 'Miguel', 'grades': {'Math': 85, 'CS': 90}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db
# Load the private key
cred = credentials.Certificate("/content/FIREBASE_KEY.json")
# Initialize the app with your database URL
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://grade8-json-db-871ff-default-rtdb.asia-southeast1.firebasedatabase.app/"})
print("Firebase connected successfully!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1431538439.py in <cell line: 0>()
#       4 cred = credentials.Certificate("/content/FIREBASE_KEY.json")
#       5 # Initialize the app with your database URL
# ----> 6 firebase_admin.initialize_app(cred, {
#       7  "databaseURL": "https://grade8-json-db-871ff-default-rtdb.asia-southeast1.firebasedatabase.app/"})
#       8 print("Firebase connected successfully!")
#
# /usr/local/lib/python3.12/dist-packages/firebase_admin/__init__.py in initialize_app(credential, options, name)
#      72
#      73     if name == _DEFAULT_APP_NAME:
# ---> 74         raise ValueError((
#      75             'The default Firebase app already exists. This means you called '
#      76             'initialize_app() more than once without providing an app name as '
#
# ...

# %%
import requests
import json
"""
The 'students' variable is already loaded from the URL in a previous cell.
Therefore, we can directly use the 'students' variable.
"""
data = students
print("JSON file loaded")
ref = db.reference("students")
for student in data["students"]:
  ref.child(str(student["id"])).set(student)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
students_ref = db.reference("students")
students_data = students_ref.get()
print(students_data)
# Out:
# {'1001': {'grades': {'CS': 88, 'Math': 92}, 'id': 1001, 'name': 'Czarina'}, '1002': {'grades': {'CS': 90, 'Math': 85}, 'id': 1002, 'name': 'Miguel'}}

# %%
for student_id, info in students_data.items():
 print(info["name"])
# Out:
# Czarina
# Miguel

# %%
for student_id, info in students_data.items():
 print(info["name"], info["grades"])
# Out:
# Czarina {'CS': 88, 'Math': 92}
# Miguel {'CS': 90, 'Math': 85}

# %%
# Fetch data from Firebase
students_data = ref.get() # returns a dictionary with keys "0", "1", ...
# Loop through each student
for key, student in students_data.items():
 name = student["name"]
 grades = student["grades"].values()
 avg = sum(grades) / len(grades)
 print(f"Student: {name}")
 print(f"Grades: {student['grades']}")
 print(f"Average: {avg:.2f}\n")
# Out:
# Student: Czarina
# Grades: {'CS': 88, 'Math': 92}
# Average: 90.00
#
# Student: Miguel
# Grades: {'CS': 90, 'Math': 85}
# Average: 87.50
